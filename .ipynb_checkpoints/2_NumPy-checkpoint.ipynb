# %%
import numpy as np

# %%
x = np.array([4,6,9])
y = np.array([11,15,12])

# %%
array_sum = x + y
array_sum
# Out:
# array([15, 21, 21])

# %%
array_mult = x * y
array_mult
# Out:
# array([ 44,  90, 108])

# %%
x_square = x**2
x_square
# Out:
# array([16, 36, 81])

# %%
x_addtwo = x + 2
x_addtwo
# Out:
# array([ 6,  8, 11])

# %%
z1 = np.vstack([x , y, array_sum])
z1
# Out:
# array([[ 4,  6,  9],
#        [11, 15, 12],
#        [15, 21, 21]])

# %%
z2 = np.hstack([x , y])
z2
# Out:
# array([ 4,  6,  9, 11, 15, 12])
