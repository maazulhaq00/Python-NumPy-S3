# %%
import numpy as np

# %%
mat1 = np.array([[77, 85,54], [17, 15,94], [66, 81,41], [78, 83,61]])

# %%
mean = np.mean(mat1)
mean
# Out:
# np.float64(62.666666666666664)

# %%
median = np.median(mat1)
median
# Out:
# np.float64(71.5)

# %%
std = np.std(mat1)
std
# Out:
# np.float64(25.144029554194812)

# %%
np.min(mat1), np.max(mat1)
# Out:
# (np.int64(15), np.int64(94))

# %%
np.sum(mat1)
# Out:
# np.int64(752)

# %%
mean_col = np.mean(mat1, axis=0) # column wise mean
mean_col
# Out:
# array([59.5, 66. , 62.5])

# %%
mean_row = np.mean(mat1, axis=1) # row wise mean
mean_row
# Out:
# array([72.        , 42.        , 62.66666667, 74.        ])
